# %%
# Import required libraries
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam

# For reproducibility
np.random.seed(42)

# Fetch gold price data for the last 50 years
gold_data = yf.download('GC=F', start='1974-01-01', end='2024-01-01', progress=False)

# Keep only the 'Adj Close' column as it reflects the adjusted closing price
gold_data = gold_data[['Adj Close']].rename(columns={'Adj Close': 'Price'})

# Sort by date
gold_data = gold_data.sort_index()

# Display the first few rows
print(gold_data.head())

# Plot the gold prices
plt.figure(figsize=(14, 7))
plt.plot(gold_data['Price'], label='Historical Gold Prices')
plt.title('Historical Gold Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(gold_data[['Price']])

# Prepare the data for LSTM
look_back = 60  # Number of previous days to consider for prediction
X, y = [], []

for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, 0])
    y.append(scaled_data[i, 0])

X, y = np.array(X), np.array(y)

# Reshape the data to fit LSTM [samples, time steps, features]
X = X.reshape((X.shape[0], X.shape[1], 1))

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X, y, epochs=20, batch_size=32, verbose=1)

# Predict future prices till 2050
future_dates = pd.date_range(start=gold_data.index[-1], end='2050-12-31', freq='D')
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back days of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, 1))
    predicted_prices.append(prediction[0, 0])
    
    # Update the data with the new prediction
    last_data = np.append(last_data[1:], prediction, axis=0)

# Transform the predictions back to original scale
predicted_prices = scaler.inverse_transform(np.array(predicted_prices).reshape(-1, 1))

# Create a DataFrame to store the predictions
future_df = pd.DataFrame({'Date': future_dates, 'Predicted Price': predicted_prices.flatten()})
future_df.set_index('Date', inplace=True)

# Plot the predictions
plt.figure(figsize=(14, 7))
plt.plot(gold_data['Price'], label='Historical Prices')
plt.plot(future_df['Predicted Price'], label='Predicted Prices')
plt.title('Gold Price Prediction till 2050')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_price_predictions_till_2050.csv')

print("File downloaded")
# Out:
#                  Price
# Date
# 2000-08-30  273.899994
# 2000-08-31  278.299988
# 2000-09-01  277.000000
# 2000-09-05  275.799988
# 2000-09-06  274.200012
# C:\Users\surve\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - loss: 0.0163
# Epoch 2/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 3.1163e-04
# Epoch 3/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - loss: 3.5341e-04
# Epoch 4/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - loss: 2.6968e-04
# Epoch 5/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 2.7235e-04
# Epoch 6/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 2.5130e-04
# Epoch 7/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - loss: 2.1448e-04
# Epoch 8/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 2.3391e-04
# Epoch 9/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 1.8144e-04
# Epoch 10/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 2.3406e-04
# Epoch 11/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 1.8496e-04
# Epoch 12/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 1.5565e-04
# Epoch 13/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 1.4714e-04
# Epoch 14/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 2.4185e-04
# Epoch 15/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 1.3606e-04
# Epoch 16/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 1.4176e-04
# Epoch 17/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 1.2973e-04
# Epoch 18/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - loss: 1.0163e-04
# Epoch 19/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 1.3217e-04
# Epoch 20/20
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 9.2172e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
# !pip install yfinance numpy pandas matplotlib scikit-learn tensorflow
# Out:
# Requirement already satisfied: yfinance in c:\users\surve\anaconda3\lib\site-packages (0.2.41)
# Requirement already satisfied: numpy in c:\users\surve\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\surve\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\surve\appdata\roaming\python\python312\site-packages (3.9.1.post1)
# Requirement already satisfied: scikit-learn in c:\users\surve\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: tensorflow in c:\users\surve\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: requests>=2.31 in c:\users\surve\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\surve\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\surve\anaconda3\lib\site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\surve\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\surve\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\surve\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\surve\anaconda3\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\surve\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\surve\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\surve\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\surve\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\surve\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\surve\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\surve\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\surve\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: webencodings in c:\users\surve\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\surve\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\surve\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\surve\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\surve\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\surve\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\surve\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\surve\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\surve\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\surve\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\surve\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\surve\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\surve\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\surve\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\surve\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\surve\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.0)

# %%
# Import required libraries
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam

# For reproducibility
np.random.seed(42)

# Fetch gold price data for the last 50 years
gold_data = yf.download('GC=F', start='1974-01-01', end='2024-01-01', progress=False)

# Fetch FED rates data
fed_data = yf.download('^IRX', start='1974-01-01', end='2024-01-01', progress=False)

# Keep necessary columns
gold_data = gold_data[['Open', 'High', 'Low', 'Close', 'Adj Close']]
fed_data = fed_data[['Adj Close']].rename(columns={'Adj Close': 'FED Rate'})

# Merge gold data with FED rates
data = gold_data.merge(fed_data, left_index=True, right_index=True, how='left')

# Fill missing FED rates with the last available value
data['FED Rate'].fillna(method='ffill', inplace=True)

# Calculate Rate of Change (ROC)
data['ROC'] = data['Adj Close'].pct_change(periods=1)

# Calculate RSI
window_length = 14
delta = data['Adj Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=window_length).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=window_length).mean()
rs = gain / loss
data['RSI'] = 100 - (100 / (1 + rs))

# Calculate MACD
ema_12 = data['Adj Close'].ewm(span=12, adjust=False).mean()
ema_26 = data['Adj Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = ema_12 - ema_26

# Drop rows with NaN values created by the technical indicators
data.dropna(inplace=True)

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Prepare the data for LSTM
look_back = 60  # Number of previous days to consider for prediction
X, y = [], []

for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, :])  # Use all features
    y.append(scaled_data[i, data.columns.get_loc('Adj Close')])  # Predict the Adj Close price

X, y = np.array(X), np.array(y)

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X, y, epochs=20, batch_size=32, verbose=1)

# Predict future prices till 2050
future_dates = pd.date_range(start=data.index[-1], end='2050-12-31', freq='D')
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back days of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]))
    predicted_prices.append(prediction[0, 0])
    
    # Update the data with the new prediction
    # Create a new row with the predicted Adj Close and same values for other features
    new_row = np.append(last_data[-1, :-1], prediction[0, 0])
    
    # Add the new row to the last_data array
    last_data = np.vstack((last_data[1:], new_row))

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), X.shape[2]))
predicted_prices_scaled[:, -1] = predicted_prices  # Fill only the last column with predictions (Adj Close)
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, -1]

# Create a DataFrame to store the predictions
future_df = pd.DataFrame({'Date': future_dates, 'Predicted Price': predicted_prices.flatten()})
future_df.set_index('Date', inplace=True)

# Plot the predictions
plt.figure(figsize=(14, 7))
plt.plot(data['Adj Close'], label='Historical Prices')
plt.plot(future_df['Predicted Price'], label='Predicted Prices')
plt.title('Gold Price Prediction till 2050')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('8to1_gold_price_predictions_till_2050.csv')
print("Download completed")
# Out:
# C:\Users\surve\AppData\Local\Temp\ipykernel_12068\2239290071.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\surve\AppData\Local\Temp\ipykernel_12068\2239290071.py:28: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\surve\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - loss: 0.0258
# Epoch 2/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 2.2682e-04
# Epoch 3/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 2.0639e-04
# Epoch 4/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.8300e-04
# Epoch 5/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.7894e-04
# Epoch 6/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.4557e-04
# Epoch 7/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.2745e-04
# Epoch 8/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.3598e-04
# Epoch 9/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.5235e-04
# Epoch 10/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.5264e-04
# Epoch 11/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.1307e-04
# Epoch 12/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.2585e-04
# Epoch 13/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.1208e-04
# Epoch 14/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 9.9629e-05
# Epoch 15/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.1397e-04
# Epoch 16/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 1.3247e-04
# Epoch 17/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 1.4775e-04
# Epoch 18/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 9.5888e-05
# Epoch 19/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.0564e-04
# Epoch 20/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 8.2862e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
# Import required libraries
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam

# For reproducibility
np.random.seed(42)

# Fetch gold price data for the last 50 years with monthly frequency
gold_data = yf.download('GC=F', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Fetch FED rates data with monthly frequency
fed_data = yf.download('^IRX', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Keep necessary columns
gold_data = gold_data[['Open', 'High', 'Low', 'Close', 'Adj Close']]
fed_data = fed_data[['Adj Close']].rename(columns={'Adj Close': 'FED Rate'})

# Merge gold data with FED rates
data = gold_data.merge(fed_data, left_index=True, right_index=True, how='left')

# Fill missing FED rates with the last available value
data['FED Rate'].fillna(method='ffill', inplace=True)

# Calculate Rate of Change (ROC)
data['ROC'] = data['Adj Close'].pct_change(periods=1)

# Calculate RSI
window_length = 14
delta = data['Adj Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=window_length).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=window_length).mean()
rs = gain / loss
data['RSI'] = 100 - (100 / (1 + rs))

# Calculate MACD
ema_12 = data['Adj Close'].ewm(span=12, adjust=False).mean()
ema_26 = data['Adj Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = ema_12 - ema_26

# Drop rows with NaN values created by the technical indicators
data.dropna(inplace=True)

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Prepare the data for LSTM
look_back = 60  # Number of previous periods (months) to consider for prediction
X, y = [], []

# We will predict Open, High, Low, and Close prices
for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, :])  # Use all features
    y.append(scaled_data[i, [0, 1, 2, 3]])  # Predict Open, High, Low, and Close prices

X, y = np.array(X), np.array(y)

# Split the data into training and testing sets
split_index = int(0.8 * len(X))
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=4))  # 4 outputs for Open, High, Low, Close

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32, verbose=1, validation_data=(X_test, y_test))

# Make predictions
predicted_train = model.predict(X_train)
predicted_test = model.predict(X_test)

# Inverse transform the predictions and actual values
predicted_train = scaler.inverse_transform(np.hstack((predicted_train, np.zeros((predicted_train.shape[0], scaled_data.shape[1] - 4)))))
predicted_test = scaler.inverse_transform(np.hstack((predicted_test, np.zeros((predicted_test.shape[0], scaled_data.shape[1] - 4)))))
y_train = scaler.inverse_transform(np.hstack((y_train, np.zeros((y_train.shape[0], scaled_data.shape[1] - 4)))))
y_test = scaler.inverse_transform(np.hstack((y_test, np.zeros((y_test.shape[0], scaled_data.shape[1] - 4)))))

# Convert predictions to DataFrame for easier plotting
train_dates = data.index[look_back:split_index + look_back]
test_dates = data.index[split_index + look_back:]

predicted_train_df = pd.DataFrame(predicted_train[:, :4], index=train_dates, columns=['Open', 'High', 'Low', 'Close'])
predicted_test_df = pd.DataFrame(predicted_test[:, :4], index=test_dates, columns=['Open', 'High', 'Low', 'Close'])

# Plot the training set predictions
plt.figure(figsize=(14, 7))
plt.plot(predicted_train_df['Close'], label='Predicted Close (Training)')
plt.plot(pd.DataFrame(y_train[:, 3], index=train_dates), label='Actual Close (Training)')
plt.title('Gold Price Prediction (Training Set)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Plot the testing set predictions
plt.figure(figsize=(14, 7))
plt.plot(predicted_test_df['Close'], label='Predicted Close (Testing)')
plt.plot(pd.DataFrame(y_test[:, 3], index=test_dates), label='Actual Close (Testing)')
plt.title('Gold Price Prediction (Testing Set)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
predicted_test_df.to_csv('8to8gold_price_predictions_till_2050.csv')
print("Download completed")
# Out:
# Epoch 1/20
# C:\Users\surve\AppData\Local\Temp\ipykernel_12068\3894584593.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\surve\AppData\Local\Temp\ipykernel_12068\3894584593.py:28: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\surve\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - loss: 0.2830 - val_loss: 0.2628
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0667 - val_loss: 0.0464
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0221 - val_loss: 0.0391
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0222 - val_loss: 0.0459
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0112 - val_loss: 0.0546
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0122 - val_loss: 0.0440
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0086 - val_loss: 0.0243
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0075 - val_loss: 0.0301
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0077 - val_loss: 0.0207
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0061 - val_loss: 0.0253
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0054 - val_loss: 0.0248
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0053 - val_loss: 0.0263
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0046 - val_loss: 0.0183
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0045 - val_loss: 0.0271
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0054 - val_loss: 0.0190
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0040 - val_loss: 0.0147
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0053 - val_loss: 0.0160
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0044 - val_loss: 0.0147
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0039 - val_loss: 0.0178
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0042 - val_loss: 0.0147
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Download completed

# %%
# Import required libraries
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam

# For reproducibility
np.random.seed(42)

# Fetch gold price data for the last 50 years with monthly frequency
gold_data = yf.download('GC=F', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Fetch FED rates data with monthly frequency
fed_data = yf.download('^IRX', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Keep necessary columns
gold_data = gold_data[['Open', 'High', 'Low', 'Close', 'Adj Close']]
fed_data = fed_data[['Adj Close']].rename(columns={'Adj Close': 'FED Rate'})

# Debug: Print the shapes and head of the original DataFrames
print("Gold DataFrame shape:", gold_data.shape)
print(gold_data.head())
print("FED DataFrame shape:", fed_data.shape)
print(fed_data.head())

# Merge gold data with FED rates
data = gold_data.merge(fed_data, left_index=True, right_index=True, how='left')

# Fill missing FED rates with the last available value
data['FED Rate'].fillna(method='ffill', inplace=True)

# Calculate Rate of Change (ROC)
data['ROC'] = data['Adj Close'].pct_change(periods=1)

# Calculate RSI
window_length = 14
delta = data['Adj Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=window_length).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=window_length).mean()
rs = gain / loss
data['RSI'] = 100 - (100 / (1 + rs))

# Calculate MACD
ema_12 = data['Adj Close'].ewm(span=12, adjust=False).mean()
ema_26 = data['Adj Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = ema_12 - ema_26

# Drop rows with NaN values created by the technical indicators
data.dropna(inplace=True)

# Debug: Print the shape and head of the merged DataFrame
print("\nMerged DataFrame shape:", data.shape)
print(data.head())

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Debug: Print the shape of the scaled data
print("\nScaled data shape:", scaled_data.shape)

# Prepare the data for LSTM
look_back = 60  # Number of previous periods (months) to consider for prediction
X, y = [], []

# We will predict Open, High, Low, and Close prices
for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, :])  # Use all features
    y.append(scaled_data[i, [0, 1, 2, 3]])  # Predict Open, High, Low, and Close prices

X, y = np.array(X), np.array(y)

# Debug: Print the shapes of X and y
print("\nX shape:", X.shape)
print("y shape:", y.shape)

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=4))  # 4 outputs for Open, High, Low, Close

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X, y, epochs=20, batch_size=32, verbose=1)

# Make predictions for future dates till 2050
future_dates = pd.date_range(start=data.index[-1], end='2050-12-31', freq='M')
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back months of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]))
    predicted_prices.append(prediction[0])
    
    # Debug: Print the shape of last_data and prediction
    print("\nLast data shape before update:", last_data.shape)
    print("Prediction shape:", prediction.shape)

    # Update the data with the new prediction
    next_input = np.vstack((last_data[1:], prediction))  # Stack arrays vertically
    last_data = next_input
    
    # Debug: Print the shape of last_data after update
    print("Last data shape after update:", last_data.shape)

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), scaled_data.shape[1]))
predicted_prices_scaled[:, :4] = predicted_prices  # Fill only the first 4 columns with predictions (Open, High, Low, Close)
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, :4]

# Create a DataFrame to store the predictions
future_df = pd.DataFrame(predicted_prices, index=future_dates, columns=['Open', 'High', 'Low', 'Close'])

# Plot the predictions
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Historical Close Prices')
plt.plot(future_df['Close'], label='Predicted Close Prices')
plt.title('Gold Price Prediction till 2050')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_price_predictions_till_2050.csv')
print("Download completed")
# Out:
# Gold DataFrame shape: (239, 5)
#                   Open        High         Low       Close   Adj Close
# Date
# 2000-09-01  277.000000  278.399994  269.000000  273.600006  273.600006
# 2000-11-01  263.899994  270.200012  263.899994  270.100006  270.100006
# 2000-12-01  269.700012  276.000000  268.000000  272.000000  272.000000
# 2001-01-01  268.399994  268.399994  262.799988  265.600006  265.600006
# 2001-02-01  266.299988  268.899994  255.000000  266.799988  266.799988
# FED DataFrame shape: (468, 1)
#             FED Rate
# Date
# 1985-01-01      8.05
# 1985-02-01      8.50
# 1985-03-01      8.18
# 1985-04-01      7.85
# 1985-05-01      7.14
#
# Merged DataFrame shape: (226, 9)
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-01-01  278.899994  287.399994  278.100006  282.100006  282.100006
# 2002-02-01  282.299988  308.000000  282.200012  296.700012  296.700012
# 2002-03-01  298.000000  304.500000  289.899994  302.600006  302.600006
# 2002-04-01  302.600006  312.500000  297.500000  308.899994  308.899994
# 2002-05-01  309.100006  329.000000  306.799988  326.500000  326.500000
#
#             FED Rate       ROC        RSI      MACD
# Date
# 2002-01-01     1.720  0.012199  55.114322  1.712014
# 2002-02-01     1.720  0.051755  61.821909  3.243340
# 2002-03-01     1.740  0.019885  66.233770  4.876791
# 2002-04-01     1.730  0.020820  67.655505  6.603547
# 2002-05-01     1.705  0.056976  76.318065  9.285154
#
# Scaled data shape: (226, 9)
#
# X shape: (166, 60, 9)
# y shape: (166, 4)
# Epoch 1/20
# C:\Users\surve\AppData\Local\Temp\ipykernel_12068\2017349847.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\surve\AppData\Local\Temp\ipykernel_12068\2017349847.py:34: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\surve\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.4634
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1253
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0350
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0237
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0179
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0124
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0095
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0097
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0072
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0071
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0054
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0049
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0045
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0041
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0034
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0035
# C:\Users\surve\AppData\Local\Temp\ipykernel_12068\2017349847.py:95: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=data.index[-1], end='2050-12-31', freq='M')
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000015EF64B7F60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 110
#     107 print("Prediction shape:", prediction.shape)
#     109 # Update the data with the new prediction
# --> 110 next_input = np.vstack((last_data[1:], prediction))  # Stack arrays vertically
#     111 last_data = next_input
#     113 # Debug: Print the shape of last_data after update
#
# File ~\anaconda3\Lib\site-packages\numpy\core\shape_base.py:289, in vstack(tup, dtype, casting)
#     287 if not isinstance(arrs, list):
#     288     arrs = [arrs]
# --> 289 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 9 and the array at index 1 has size 4

# %%
# Make predictions for future dates till 2050
future_dates = pd.date_range(start=data.index[-1], end='2050-12-31', freq='M')
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back months of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]))
    predicted_prices.append(prediction[0])
    
    # Debug: Print the shape of last_data and prediction
    print("\nLast data shape before update:", last_data.shape)
    print("Prediction shape:", prediction.shape)

    # Update the data with the new prediction
    # Append the prediction to the appropriate columns of last_data
    next_input = np.copy(last_data[1:])  # Move the data forward
    next_input = np.hstack((next_input[:, :-4], prediction))  # Replace last 4 columns with the prediction
    last_data = next_input
    
    # Debug: Print the shape of last_data after update
    print("Last data shape after update:", last_data.shape)

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), scaled_data.shape[1]))
predicted_prices_scaled[:, :4] = predicted_prices  # Fill only the first 4 columns with predictions (Open, High, Low, Close)
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, :4]

# Create a DataFrame to store the predictions
future_df = pd.DataFrame(predicted_prices, index=future_dates, columns=['Open', 'High', 'Low', 'Close'])

# Plot the predictions
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Historical Close Prices')
plt.plot(future_df['Close'], label='Predicted Close Prices')
plt.title('Gold Price Prediction till 2050')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_price_predictions_till_2050.csv')
print("Download completed")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# C:\Users\surve\AppData\Local\Temp\ipykernel_12068\1490887795.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=data.index[-1], end='2050-12-31', freq='M')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 19
#      16 # Update the data with the new prediction
#      17 # Append the prediction to the appropriate columns of last_data
#      18 next_input = np.copy(last_data[1:])  # Move the data forward
# ---> 19 next_input = np.hstack((next_input[:, :-4], prediction))  # Replace last 4 columns with the prediction
#      20 last_data = next_input
#      22 # Debug: Print the shape of last_data after update
#
# File ~\anaconda3\Lib\site-packages\numpy\core\shape_base.py:359, in hstack(tup, dtype, casting)
#     357     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     358 else:
# --> 359     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 59 and the array at index 1 has size 1

# %%
# Make predictions for future dates till 2050
future_dates = pd.date_range(start=data.index[-1], end='2050-12-31', freq='ME')  # Use 'ME' for month-end frequency
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back months of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]))
    predicted_prices.append(prediction[0])

    # Debug: Print the shape of last_data and prediction
    print("\nLast data shape before update:", last_data.shape)
    print("Prediction shape:", prediction.shape)

    # Update the data with the new prediction
    # Replace the last four columns in the last row of last_data with the new prediction
    next_input = np.vstack([last_data[1:], np.zeros((1, last_data.shape[1]))])  # Move data forward, add a new row of zeros
    next_input[-1, -4:] = prediction  # Replace the last four columns with the prediction
    last_data = next_input

    # Debug: Print the shape of last_data after update
    print("Last data shape after update:", last_data.shape)

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), scaled_data.shape[1]))
predicted_prices_scaled[:, -4:] = predicted_prices  # Fill only the last four columns with predictions (Open, High, Low, Close)
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, -4:]

# Create a DataFrame to store the predictions
future_df = pd.DataFrame(predicted_prices, index=future_dates, columns=['Open', 'High', 'Low', 'Close'])

# Plot the predictions
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Historical Close Prices')
plt.plot(future_df['Close'], label='Predicted Close Prices')
plt.title('Gold Price Prediction till 2050')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_price_predictions_till_2050.csv')
print("Download completed")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# Last data shape before update: (60, 9)
# Prediction shape: (1, 4)
# Last data shape after update: (60, 9)
# Download completed

# %%
# Import required libraries
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam

# For reproducibility
np.random.seed(42)

# Fetch gold price data for the last 50 years with monthly frequency
gold_data = yf.download('GC=F', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Fetch FED rates data with monthly frequency
fed_data = yf.download('^IRX', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Keep necessary columns
gold_data = gold_data[['Open', 'High', 'Low', 'Close', 'Adj Close']]
fed_data = fed_data[['Adj Close']].rename(columns={'Adj Close': 'FED Rate'})

# Merge gold data with FED rates
data = gold_data.merge(fed_data, left_index=True, right_index=True, how='left')

# Fill missing FED rates with the last available value
data['FED Rate'].fillna(method='ffill', inplace=True)

# Calculate Rate of Change (ROC)
data['ROC'] = data['Adj Close'].pct_change(periods=1)

# Calculate RSI
window_length = 14
delta = data['Adj Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=window_length).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=window_length).mean()
rs = gain / loss
data['RSI'] = 100 - (100 / (1 + rs))

# Calculate MACD
ema_12 = data['Adj Close'].ewm(span=12, adjust=False).mean()
ema_26 = data['Adj Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = ema_12 - ema_26

# Drop rows with NaN values created by the technical indicators
data.dropna(inplace=True)

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Prepare the data for LSTM
look_back = 60  # Number of previous periods (months) to consider for prediction
X, y = [], []

# We will predict Open, High, Low, and Close prices
for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, :])  # Use all features
    y.append(scaled_data[i, [0, 1, 2, 3]])  # Predict Open, High, Low, and Close prices

X, y = np.array(X), np.array(y)

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=False))
model.add(Dense(units=50))
model.add(Dense(units=4))  # 4 outputs for Open, High, Low, Close

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X, y, epochs=100, batch_size=100, verbose=1)

# Make predictions for future dates till 2050
future_dates = pd.date_range(start=data.index[-1], end='2050-12-31', freq='ME')  # Use 'ME' for month-end frequency
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back months of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]), verbose=0)
    predicted_prices.append(prediction[0])

    # Update the data with the new prediction
    last_data = np.vstack([last_data[1:], np.zeros((1, last_data.shape[1]))])  # Shift data forward
    last_data[-1, :4] = prediction  # Update with predicted Open, High, Low, Close

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), scaled_data.shape[1]))
predicted_prices_scaled[:, :4] = predicted_prices  # Fill only the first four columns with predictions (Open, High, Low, Close)
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, :4]

# Create a DataFrame to store the predictions
future_df = pd.DataFrame(predicted_prices, index=future_dates, columns=['Open', 'High', 'Low', 'Close'])

# Plot the predictions
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Historical Close Prices')
plt.plot(future_df['Close'], label='Predicted Close Prices')
plt.title('Gold Price Prediction till 2050')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_price_predictions_till_2050.csv')
print("Download completed")
# Out:
# C:\Users\surve\AppData\Local\Temp\ipykernel_13776\21104146.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\surve\AppData\Local\Temp\ipykernel_13776\21104146.py:28: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\surve\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - loss: 0.4276
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step - loss: 0.2209
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step - loss: 0.0402
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 884ms/step - loss: 0.0461
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 786ms/step - loss: 0.0313
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 975ms/step - loss: 0.0239
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 728ms/step - loss: 0.0259
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 587ms/step - loss: 0.0271
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 439ms/step - loss: 0.0233
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 537ms/step - loss: 0.0185
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 611ms/step - loss: 0.0153
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 808ms/step - loss: 0.0212
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 441ms/step - loss: 0.0151
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 466ms/step - loss: 0.0130
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 492ms/step - loss: 0.0122
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 491ms/step - loss: 0.0095
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 437ms/step - loss: 0.0093
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 646ms/step - loss: 0.0074
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 429ms/step - loss: 0.0064
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step - loss: 0.0061
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 420ms/step - loss: 0.0054
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 462ms/step - loss: 0.0044
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 997ms/step - loss: 0.0040
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 456ms/step - loss: 0.0041
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 466ms/step - loss: 0.0031
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 501ms/step - loss: 0.0041
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 452ms/step - loss: 0.0031
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 459ms/step - loss: 0.0027
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 456ms/step - loss: 0.0027
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 626ms/step - loss: 0.0025
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 515ms/step - loss: 0.0024
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 461ms/step - loss: 0.0024
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 467ms/step - loss: 0.0024
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 463ms/step - loss: 0.0024
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 910ms/step - loss: 0.0023
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 455ms/step - loss: 0.0022
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 424ms/step - loss: 0.0020
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 872ms/step - loss: 0.0021
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 743ms/step - loss: 0.0021
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 447ms/step - loss: 0.0019
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 437ms/step - loss: 0.0021
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 968ms/step - loss: 0.0022
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 786ms/step - loss: 0.0022
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 476ms/step - loss: 0.0023
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 474ms/step - loss: 0.0020
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 496ms/step - loss: 0.0018
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 677ms/step - loss: 0.0020
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 457ms/step - loss: 0.0021
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 479ms/step - loss: 0.0017
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 480ms/step - loss: 0.0026
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - loss: 0.0018
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 601ms/step - loss: 0.0018
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 444ms/step - loss: 0.0020
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 472ms/step - loss: 0.0019
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 489ms/step - loss: 0.0018
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 474ms/step - loss: 0.0021
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 462ms/step - loss: 0.0021
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 470ms/step - loss: 0.0020
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 489ms/step - loss: 0.0018
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 477ms/step - loss: 0.0018
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 444ms/step - loss: 0.0018
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 458ms/step - loss: 0.0018
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 470ms/step - loss: 0.0018
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 469ms/step - loss: 0.0017
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 832ms/step - loss: 0.0018
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 469ms/step - loss: 0.0016
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 591ms/step - loss: 0.0019
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 482ms/step - loss: 0.0019
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 446ms/step - loss: 0.0017
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 475ms/step - loss: 0.0019
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 490ms/step - loss: 0.0019
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - loss: 0.0018
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 438ms/step - loss: 0.0019
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 941ms/step - loss: 0.0019
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 855ms/step - loss: 0.0017
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 477ms/step - loss: 0.0018
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 451ms/step - loss: 0.0018
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 493ms/step - loss: 0.0019
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 479ms/step - loss: 0.0018
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 463ms/step - loss: 0.0019
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 462ms/step - loss: 0.0018
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 462ms/step - loss: 0.0020
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 495ms/step - loss: 0.0019
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 480ms/step - loss: 0.0023
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 455ms/step - loss: 0.0020
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 989ms/step - loss: 0.0020
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 538ms/step - loss: 0.0019
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - loss: 0.0020
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 457ms/step - loss: 0.0019
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 821ms/step - loss: 0.0018
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 810ms/step - loss: 0.0019
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 451ms/step - loss: 0.0018
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 447ms/step - loss: 0.0016
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 473ms/step - loss: 0.0017
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 477ms/step - loss: 0.0020
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 484ms/step - loss: 0.0019
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 825ms/step - loss: 0.0022
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 534ms/step - loss: 0.0018
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 501ms/step - loss: 0.0016
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 460ms/step - loss: 0.0021
# Download completed

# %%
# !pip install mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in c:\users\surve\appdata\roaming\python\python312\site-packages (from mplfinance) (3.9.1.post1)
# Requirement already satisfied: pandas in c:\users\surve\anaconda3\lib\site-packages (from mplfinance) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib->mplfinance) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib->mplfinance) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\surve\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\surve\anaconda3\lib\site-packages (from pandas->mplfinance) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\surve\anaconda3\lib\site-packages (from pandas->mplfinance) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\surve\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/75.0 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/75.0 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/75.0 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/75.0 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/75.0 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/75.0 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    ---------------- ----------------------- 30.7/75.0 kB 72.6 kB/s eta 0:00:01
#    --------------------- ------------------ 41.0/75.0 kB 40.1 kB/s eta 0:00:01
#    -------------------------------------- - 71.7/75.0 kB 74.1 kB/s eta 0:00:01
#    ---------------------------------------- 75.0/75.0 kB 76.7 kB/s eta 0:00:00
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import pandas as pd

# Read the CSV file
file_path = r'C:\Users\surve\OneDrive\Desktop\Github Repository\Repository4 - Gold Predictions\gold_price_predictions_till_2050_new.csv'
df = pd.read_csv(file_path)

# Convert the 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%y')

# Set 'Date' as the index
df.set_index('Date', inplace=True)

import mplfinance as mpf

# Prepare the data for mplfinance
df.index.name = 'Date'

# Plotting
mpf.plot(df, type='candle', style='charles', title='Gold Price Candlestick Chart', ylabel='Price')

# %%
# Plot the predictions
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Historical Close Prices', color='blue')
plt.plot(future_df['Close'], label='Predicted Close Prices', linestyle='--', color='green')
plt.title('Gold Price Prediction till 2050')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Import required libraries
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam

# For reproducibility
np.random.seed(42)

# Fetch gold price data for the last 50 years with monthly frequency
gold_data = yf.download('GC=F', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Fetch FED rates data with monthly frequency
fed_data = yf.download('^IRX', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Keep necessary columns
gold_data = gold_data[['Open', 'High', 'Low', 'Close', 'Adj Close']]
fed_data = fed_data[['Adj Close']].rename(columns={'Adj Close': 'FED Rate'})

# Merge gold data with FED rates
data = gold_data.merge(fed_data, left_index=True, right_index=True, how='left')

# Fill missing FED rates with the last available value
data['FED Rate'].fillna(method='ffill', inplace=True)

# Calculate Rate of Change (ROC)
data['ROC'] = data['Adj Close'].pct_change(periods=1)

# Calculate RSI
window_length = 14
delta = data['Adj Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=window_length).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=window_length).mean()
rs = gain / loss
data['RSI'] = 100 - (100 / (1 + rs))

# Calculate MACD
ema_12 = data['Adj Close'].ewm(span=12, adjust=False).mean()
ema_26 = data['Adj Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = ema_12 - ema_26

# Drop rows with NaN values created by the technical indicators
data.dropna(inplace=True)

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Prepare the data for LSTM
look_back = 60  # Number of previous periods (months) to consider for prediction
X, y = [], []

# We will predict Open, High, Low, and Close prices
for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, :])  # Use all features
    y.append(scaled_data[i, [0, 1, 2, 3]])  # Predict Open, High, Low, and Close prices

X, y = np.array(X), np.array(y)

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=False))
model.add(Dense(units=50))
model.add(Dense(units=4))  # 4 outputs for Open, High, Low, Close

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X, y, epochs=100, batch_size=100, verbose=1)

# Make predictions for future dates till 2050
future_dates = pd.date_range(start=data.index[-1], end='2030-12-31', freq='ME')  # Use 'ME' for month-end frequency
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back months of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]), verbose=0)
    predicted_prices.append(prediction[0])

    # Update the data with the new prediction
    last_data = np.vstack([last_data[1:], np.zeros((1, last_data.shape[1]))])  # Shift data forward
    last_data[-1, :4] = prediction  # Update with predicted Open, High, Low, Close

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), scaled_data.shape[1]))
predicted_prices_scaled[:, :4] = predicted_prices  # Fill only the first four columns with predictions (Open, High, Low, Close)
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, :4]

# Create a DataFrame to store the predictions
future_df = pd.DataFrame(predicted_prices, index=future_dates, columns=['Open', 'High', 'Low', 'Close'])

# Plot the predictions
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Historical Close Prices')
plt.plot(future_df['Close'], label='Predicted Close Prices')
plt.title('Gold Price Prediction till 2050')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_price_predictions_till_2050.csv')
print("Download completed")
# Out:
# C:\Users\Snapper\AppData\Local\Temp\ipykernel_15136\1100177033.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\Snapper\AppData\Local\Temp\ipykernel_15136\1100177033.py:28: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['FED Rate'].fillna(method='ffill', inplace=True)
# C:\Users\Snapper\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 469ms/step - loss: 0.4236
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 472ms/step - loss: 0.1676
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 460ms/step - loss: 0.0497
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 476ms/step - loss: 0.0752
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 464ms/step - loss: 0.0524
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 481ms/step - loss: 0.0358
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 467ms/step - loss: 0.0257
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 467ms/step - loss: 0.0272
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 464ms/step - loss: 0.0288
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 454ms/step - loss: 0.0263
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 471ms/step - loss: 0.0238
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 443ms/step - loss: 0.0232
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 459ms/step - loss: 0.0233
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 486ms/step - loss: 0.0243
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 481ms/step - loss: 0.0222
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 479ms/step - loss: 0.0206
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 475ms/step - loss: 0.0219
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 470ms/step - loss: 0.0217
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 471ms/step - loss: 0.0223
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 455ms/step - loss: 0.0207
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 470ms/step - loss: 0.0210
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - loss: 0.0198
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 456ms/step - loss: 0.0208
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 479ms/step - loss: 0.0195
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 471ms/step - loss: 0.0201
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 479ms/step - loss: 0.0184
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 460ms/step - loss: 0.0146
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 481ms/step - loss: 0.0120
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 454ms/step - loss: 0.0263
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 472ms/step - loss: 0.0183
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 446ms/step - loss: 0.0136
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 479ms/step - loss: 0.0150
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 445ms/step - loss: 0.0093
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step - loss: 0.0075
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step - loss: 0.0095
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step - loss: 0.0048
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step - loss: 0.0068
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step - loss: 0.0051
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step - loss: 0.0044
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 476ms/step - loss: 0.0031
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 494ms/step - loss: 0.0043
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 465ms/step - loss: 0.0031
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - loss: 0.0027
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 469ms/step - loss: 0.0032
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 474ms/step - loss: 0.0026
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 470ms/step - loss: 0.0026
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 495ms/step - loss: 0.0023
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 489ms/step - loss: 0.0023
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 491ms/step - loss: 0.0021
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 481ms/step - loss: 0.0021
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 479ms/step - loss: 0.0020
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - loss: 0.0020
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 478ms/step - loss: 0.0019
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 478ms/step - loss: 0.0019
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 498ms/step - loss: 0.0019
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - loss: 0.0019
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step - loss: 0.0019
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - loss: 0.0018
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 454ms/step - loss: 0.0018
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 499ms/step - loss: 0.0019
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 465ms/step - loss: 0.0018
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 485ms/step - loss: 0.0017
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 451ms/step - loss: 0.0018
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 493ms/step - loss: 0.0017
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 471ms/step - loss: 0.0017
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 482ms/step - loss: 0.0017
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - loss: 0.0017
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 489ms/step - loss: 0.0017
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step - loss: 0.0019
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step - loss: 0.0017
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step - loss: 0.0018
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step - loss: 0.0019
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step - loss: 0.0016
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 499ms/step - loss: 0.0017
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step - loss: 0.0017
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - loss: 0.0017
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step - loss: 0.0017
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 499ms/step - loss: 0.0018
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - loss: 0.0017
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step - loss: 0.0018
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - loss: 0.0017
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step - loss: 0.0018
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 497ms/step - loss: 0.0017
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step - loss: 0.0018
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - loss: 0.0018
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step - loss: 0.0017
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 491ms/step - loss: 0.0017
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 490ms/step - loss: 0.0016
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 488ms/step - loss: 0.0017
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - loss: 0.0019
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - loss: 0.0018
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - loss: 0.0017
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 497ms/step - loss: 0.0018
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - loss: 0.0017
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: 0.0018
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - loss: 0.0019
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - loss: 0.0017
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - loss: 0.0017
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step - loss: 0.0016
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - loss: 0.0017
# Download completed

# %%
# Import required libraries
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam
from keras.losses import Huber

# For reproducibility
np.random.seed(42)

# Fetch gold price data for the last 50 years with daily frequency
gold_data = yf.download('GC=F', start='1974-01-01', end='2024-01-01', interval= '1mo', progress=False)

# Fetch FED rates data with daily frequency
fed_data = yf.download('^IRX', start='1974-01-01', end='2024-01-01', interval= '1mo', progress=False)

# Keep necessary columns
gold_data = gold_data[['Open', 'High', 'Low', 'Close', 'Adj Close']]
fed_data = fed_data[['Adj Close']].rename(columns={'Adj Close': 'FED Rate'})

# Merge gold data with FED rates
data = gold_data.merge(fed_data, left_index=True, right_index=True, how='left')

# Check initial data
print("Initial Data Shape:", data.shape)
print(data.head())

# Fill missing FED rates with the last available value
data['FED Rate'] = data['FED Rate'].fillna(method='ffill')

# Calculate Rate of Change (ROC)
data['ROC'] = data['Adj Close'].pct_change(periods=1)

# Calculate RSI
window_length = 14
delta = data['Adj Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=window_length).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=window_length).mean()
data['RSI'] = 100 - (100 / (1 + (gain / loss)))

# Calculate MACD
ema_12 = data['Adj Close'].ewm(span=12, adjust=False).mean()
ema_26 = data['Adj Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = ema_12 - ema_26

# Drop rows with NaN values created by the technical indicators
print("Data Shape Before Dropna:", data.shape)
data = data.dropna()
print("Data Shape After Dropna:", data.shape)
print(data.head())

# Define look_back period
look_back = 60  # Number of previous periods (days) to consider for prediction

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))

# Check if there is data to scale
if data.empty or len(data) <= look_back:
    raise ValueError("Insufficient data for scaling. Ensure data is correctly processed.")

scaled_data = scaler.fit_transform(data)

# Prepare the data for LSTM
X, y = [], []

# We will predict Open, High, Low, and Close prices
for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, :])  # Use all features
    y.append(scaled_data[i, [0, 1, 2, 3]])  # Predict Open, High, Low, and Close prices

X, y = np.array(X), np.array(y)

# Check shapes of X and y
print("X Shape:", X.shape)
print("y Shape:", y.shape)

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=False))
model.add(Dense(units=50))
model.add(Dense(units=4))  # 4 outputs for Open, High, Low, Close

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss= Huber(delta=1.0))

# Train the model
model.fit(X, y, epochs=100, batch_size=100, verbose=1)

# Make predictions for future dates till 2030
future_dates = pd.date_range(start=data.index[-1], end='2040-12-31', freq='ME')  # Use 'D' for daily frequency
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back days of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]), verbose=0)
    predicted_prices.append(prediction[0])

    # Update the data with the new prediction
    last_data = np.vstack([last_data[1:], np.zeros((1, last_data.shape[1]))])  # Shift data forward
    last_data[-1, :4] = prediction  # Update with predicted Open, High, Low, Close

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), scaled_data.shape[1]))
predicted_prices_scaled[:, :4] = predicted_prices  # Fill only the first four columns with predictions (Open, High, Low, Close)
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, :4]

# Create a DataFrame to store the predictions
future_df = pd.DataFrame(predicted_prices, index=future_dates, columns=['Open', 'High', 'Low', 'Close'])

# Plot the predictions
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Historical Close Prices')
plt.plot(future_df['Close'], label='Predicted Close Prices')
plt.title('Gold Price Prediction till 2030')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_price_predictions_till_2030.csv')
print("Download completed")
# Out:
# Initial Data Shape: (239, 6)
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-09-01  277.000000  278.399994  269.000000  273.600006  273.600006
# 2000-11-01  263.899994  270.200012  263.899994  270.100006  270.100006
# 2000-12-01  269.700012  276.000000  268.000000  272.000000  272.000000
# 2001-01-01  268.399994  268.399994  262.799988  265.600006  265.600006
# 2001-02-01  266.299988  268.899994  255.000000  266.799988  266.799988
#
#             FED Rate
# Date
# 2000-09-01      6.03
# 2000-11-01      6.01
# 2000-12-01      5.73
# 2001-01-01      4.84
# 2001-02-01      4.72
# Data Shape Before Dropna: (239, 9)
# Data Shape After Dropna: (226, 9)
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-01-01  278.899994  287.399994  278.100006  282.100006  282.100006
# 2002-02-01  282.299988  308.000000  282.200012  296.700012  296.700012
# 2002-03-01  298.000000  304.500000  289.899994  302.600006  302.600006
# 2002-04-01  302.600006  312.500000  297.500000  308.899994  308.899994
# 2002-05-01  309.100006  329.000000  306.799988  326.500000  326.500000
#
#             FED Rate       ROC        RSI      MACD
# Date
# 2002-01-01     1.720  0.012199  55.114322  1.712014
# 2002-02-01     1.720  0.051755  61.821909  3.243340
# 2002-03-01     1.740  0.019885  66.233770  4.876791
# 2002-04-01     1.730  0.020820  67.655505  6.603547
# 2002-05-01     1.705  0.056976  76.318065  9.285154
# X Shape: (166, 60, 9)
# y Shape: (166, 4)
# C:\Users\Snapper\AppData\Local\Temp\ipykernel_3976\158796900.py:33: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['FED Rate'] = data['FED Rate'].fillna(method='ffill')
# C:\Users\Snapper\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 16s 359ms/step - loss: 0.2080
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 378ms/step - loss: 0.0897
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 385ms/step - loss: 0.0217
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step - loss: 0.0285
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - loss: 0.0190
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step - loss: 0.0129
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 383ms/step - loss: 0.0154
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 373ms/step - loss: 0.0140
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - loss: 0.0116
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - loss: 0.0113
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 380ms/step - loss: 0.0124
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 399ms/step - loss: 0.0119
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step - loss: 0.0110
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 387ms/step - loss: 0.0099
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step - loss: 0.0102
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step - loss: 0.0092
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step - loss: 0.0083
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 399ms/step - loss: 0.0068
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step - loss: 0.0111
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 402ms/step - loss: 0.0098
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - loss: 0.0071
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 394ms/step - loss: 0.0072
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 383ms/step - loss: 0.0071
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step - loss: 0.0050
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step - loss: 0.0037
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 407ms/step - loss: 0.0041
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 416ms/step - loss: 0.0026
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 378ms/step - loss: 0.0024
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 402ms/step - loss: 0.0023
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 461ms/step - loss: 0.0016
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step - loss: 0.0018
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 429ms/step - loss: 0.0017
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 467ms/step - loss: 0.0013
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step - loss: 0.0013
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 392ms/step - loss: 0.0015
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - loss: 0.0014
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 383ms/step - loss: 0.0014
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 402ms/step - loss: 0.0011
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - loss: 0.0012
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step - loss: 0.0012
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step - loss: 0.0015
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step - loss: 0.0013
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 411ms/step - loss: 0.0011
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 400ms/step - loss: 0.0013
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 408ms/step - loss: 0.0013
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 383ms/step - loss: 0.0011
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step - loss: 0.0012
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 388ms/step - loss: 9.5233e-04
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step - loss: 9.3235e-04
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 402ms/step - loss: 9.5887e-04
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 394ms/step - loss: 9.3532e-04
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step - loss: 9.9870e-04
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 425ms/step - loss: 9.1635e-04
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 393ms/step - loss: 9.9506e-04
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step - loss: 0.0011
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - loss: 0.0012
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 415ms/step - loss: 0.0010
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step - loss: 9.0315e-04
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 388ms/step - loss: 9.6624e-04
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 442ms/step - loss: 0.0012
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step - loss: 0.0011
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 407ms/step - loss: 9.9407e-04
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 393ms/step - loss: 0.0011
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - loss: 0.0011
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 427ms/step - loss: 0.0012
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 406ms/step - loss: 9.9267e-04
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 420ms/step - loss: 9.9428e-04
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 416ms/step - loss: 0.0010
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 393ms/step - loss: 0.0012
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 394ms/step - loss: 9.6794e-04
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step - loss: 9.2459e-04
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 457ms/step - loss: 8.6715e-04
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 393ms/step - loss: 9.6887e-04
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 408ms/step - loss: 9.2666e-04
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 378ms/step - loss: 8.8198e-04
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 400ms/step - loss: 8.5764e-04
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 445ms/step - loss: 8.7351e-04
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 397ms/step - loss: 8.7993e-04
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 424ms/step - loss: 8.4493e-04
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 408ms/step - loss: 8.7769e-04
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 392ms/step - loss: 8.4082e-04
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 449ms/step - loss: 8.5901e-04
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 425ms/step - loss: 8.3905e-04
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 390ms/step - loss: 8.6030e-04
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 409ms/step - loss: 9.1428e-04
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 406ms/step - loss: 8.5763e-04
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 377ms/step - loss: 8.6276e-04
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 398ms/step - loss: 8.5589e-04
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 473ms/step - loss: 8.5169e-04
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 405ms/step - loss: 8.6793e-04
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 410ms/step - loss: 8.4393e-04
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 455ms/step - loss: 8.6112e-04
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 407ms/step - loss: 8.6111e-04
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - loss: 9.0008e-04
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 442ms/step - loss: 8.5672e-04
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 405ms/step - loss: 8.2877e-04
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 428ms/step - loss: 8.4085e-04
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - loss: 8.1523e-04
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 428ms/step - loss: 9.2375e-04
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - loss: 9.1467e-04
# Download completed

# %%
# Import required libraries
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam
from keras.losses import Huber

# For reproducibility
np.random.seed(42)

# Fetch gold price data for the last 50 years with monthly frequency
gold_data = yf.download('GC=F', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Keep necessary columns
gold_data = gold_data[['Open', 'High', 'Low', 'Close', 'Adj Close']]

# Check initial data
print("Initial Data Shape:", gold_data.shape)
print(gold_data.head())

# Calculate Rate of Change (ROC)
gold_data['ROC'] = gold_data['Adj Close'].pct_change(periods=1)

# Calculate RSI
window_length = 14
delta = gold_data['Adj Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=window_length).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=window_length).mean()
gold_data['RSI'] = 100 - (100 / (1 + (gain / loss)))

# Calculate MACD
ema_12 = gold_data['Adj Close'].ewm(span=12, adjust=False).mean()
ema_26 = gold_data['Adj Close'].ewm(span=26, adjust=False).mean()
gold_data['MACD'] = ema_12 - ema_26

# Drop rows with NaN values created by the technical indicators
gold_data = gold_data.dropna()
print("Data Shape After Dropna:", gold_data.shape)
print(gold_data.head())

# Define look_back period
look_back = 60  # Number of previous periods (months) to consider for prediction

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))

# Check if there is data to scale
if gold_data.empty or len(gold_data) <= look_back:
    raise ValueError("Insufficient data for scaling. Ensure data is correctly processed.")

scaled_data = scaler.fit_transform(gold_data)

# Prepare the data for LSTM
X, y = [], []

# We will predict Open, High, Low, and Close prices
for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, :])  # Use all features
    y.append(scaled_data[i, :4])  # Predict Open, High, Low, Close prices 

X, y = np.array(X), np.array(y)

# Check shapes of X and y
print("X Shape:", X.shape)
print("y Shape:", y.shape)

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=False))
model.add(Dense(units=50))
model.add(Dense(units=4))  # 4 outputs for Open, High, Low, Close

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss=Huber(delta=1.0))

# Train the model
model.fit(X, y, epochs=100, batch_size=100, verbose=1)

# Make predictions for future dates till 2040
future_dates = pd.date_range(start=gold_data.index[-1], end='2040-12-31', freq='M')  # Use 'M' for monthly frequency
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back periods of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]), verbose=0)
    predicted_prices.append(prediction[0])

    # Update the data with the new prediction
    last_data = np.vstack([last_data[1:], np.zeros((1, last_data.shape[1]))])  # Shift data forward
    last_data[-1, :4] = prediction  # Update with predicted Open, High, Low, Close

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), scaled_data.shape[1]))
predicted_prices_scaled[:, :4] = predicted_prices  # Fill only the first four columns with predictions (Open, High, Low, Close)
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, :4]

# Create DataFrame to store the predictions
future_df = pd.DataFrame(predicted_prices, index=future_dates, columns=['Open', 'High', 'Low', 'Close'])

# Plot the predictions for Close Prices
plt.figure(figsize=(14, 7))
plt.plot(gold_data['Close'], label='Historical Close Prices')
plt.plot(future_df['Close'], label='Predicted Close Prices')
plt.title('Gold Price Prediction till 2040')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_price_predictions_till_2040.csv')
print("Download completed")
# Out:
# Initial Data Shape: (239, 5)
#                   Open        High         Low       Close   Adj Close
# Date
# 2000-09-01  277.000000  278.399994  269.000000  273.600006  273.600006
# 2000-11-01  263.899994  270.200012  263.899994  270.100006  270.100006
# 2000-12-01  269.700012  276.000000  268.000000  272.000000  272.000000
# 2001-01-01  268.399994  268.399994  262.799988  265.600006  265.600006
# 2001-02-01  266.299988  268.899994  255.000000  266.799988  266.799988
# Data Shape After Dropna: (226, 8)
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-01-01  278.899994  287.399994  278.100006  282.100006  282.100006
# 2002-02-01  282.299988  308.000000  282.200012  296.700012  296.700012
# 2002-03-01  298.000000  304.500000  289.899994  302.600006  302.600006
# 2002-04-01  302.600006  312.500000  297.500000  308.899994  308.899994
# 2002-05-01  309.100006  329.000000  306.799988  326.500000  326.500000
#
#                  ROC        RSI      MACD
# Date
# 2002-01-01  0.012199  55.114322  1.712014
# 2002-02-01  0.051755  61.821909  3.243340
# 2002-03-01  0.019885  66.233770  4.876791
# 2002-04-01  0.020820  67.655505  6.603547
# 2002-05-01  0.056976  76.318065  9.285154
# X Shape: (166, 60, 8)
# y Shape: (166, 4)
# C:\Users\Snapper\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 15s 328ms/step - loss: 0.2091
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - loss: 0.0689
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - loss: 0.0197
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 349ms/step - loss: 0.0359
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - loss: 0.0202
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - loss: 0.0176
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - loss: 0.0180
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step - loss: 0.0125
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step - loss: 0.0154
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - loss: 0.0148
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - loss: 0.0113
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - loss: 0.0109
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step - loss: 0.0123
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 356ms/step - loss: 0.0121
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - loss: 0.0100
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - loss: 0.0106
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0115
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - loss: 0.0108
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 385ms/step - loss: 0.0105
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - loss: 0.0105
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 349ms/step - loss: 0.0109
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step - loss: 0.0108
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - loss: 0.0103
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - loss: 0.0106
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - loss: 0.0103
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step - loss: 0.0105
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - loss: 0.0100
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - loss: 0.0099
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - loss: 0.0102
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - loss: 0.0102
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - loss: 0.0103
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 372ms/step - loss: 0.0100
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - loss: 0.0103
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step - loss: 0.0098
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - loss: 0.0103
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - loss: 0.0100
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step - loss: 0.0102
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 329ms/step - loss: 0.0101
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - loss: 0.0103
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step - loss: 0.0099
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - loss: 0.0102
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - loss: 0.0098
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0099
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - loss: 0.0100
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - loss: 0.0097
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step - loss: 0.0094
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - loss: 0.0089
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - loss: 0.0089
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - loss: 0.0162
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 353ms/step - loss: 0.0154
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step - loss: 0.0118
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - loss: 0.0123
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - loss: 0.0127
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - loss: 0.0132
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 356ms/step - loss: 0.0110
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - loss: 0.0109
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 331ms/step - loss: 0.0114
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 312ms/step - loss: 0.0111
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - loss: 0.0107
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - loss: 0.0105
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 331ms/step - loss: 0.0107
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - loss: 0.0102
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 348ms/step - loss: 0.0104
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 394ms/step - loss: 0.0104
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 401ms/step - loss: 0.0106
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step - loss: 0.0103
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 373ms/step - loss: 0.0105
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 388ms/step - loss: 0.0099
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step - loss: 0.0100
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - loss: 0.0099
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - loss: 0.0102
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - loss: 0.0100
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 356ms/step - loss: 0.0103
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - loss: 0.0097
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 445ms/step - loss: 0.0102
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - loss: 0.0104
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step - loss: 0.0101
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 329ms/step - loss: 0.0098
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 356ms/step - loss: 0.0098
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step - loss: 0.0099
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 330ms/step - loss: 0.0102
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 330ms/step - loss: 0.0101
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 329ms/step - loss: 0.0103
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step - loss: 0.0097
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 453ms/step - loss: 0.0098
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - loss: 0.0100
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0095
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step - loss: 0.0101
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0095
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0099
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - loss: 0.0095
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0096
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - loss: 0.0091
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0087
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - loss: 0.0097
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - loss: 0.0093
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0098
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0083
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 406ms/step - loss: 0.0088
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - loss: 0.0066
# C:\Users\Snapper\AppData\Local\Temp\ipykernel_3976\3838681958.py:92: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=gold_data.index[-1], end='2040-12-31', freq='M')  # Use 'M' for monthly frequency
# Download completed

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam
from keras.losses import MeanSquaredError  # Using MSE as the loss function

# For reproducibility
np.random.seed(42)

# Fetch gold price data for the last 50 years with monthly frequency
gold_data = yf.download('GC=F', start='1974-01-01', end='2024-01-01', interval='1mo', progress=False)

# Keep necessary columns
gold_data = gold_data[['Open', 'High', 'Low', 'Close', 'Adj Close']]

# Check initial data
print("Initial Data Shape:", gold_data.shape)
print(gold_data.head())

# Drop rows with NaN values
gold_data = gold_data.dropna()

# Define look_back period
look_back = 60  # Number of previous periods (days) to consider for prediction

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))

# Check if there is data to scale
if gold_data.empty or len(gold_data) <= look_back:
    raise ValueError("Insufficient data for scaling. Ensure data is correctly processed.")

scaled_data = scaler.fit_transform(gold_data)

# Prepare the data for LSTM
X, y = [], []

# We will predict only the 'Adj Close' price
for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, :])  # Use all features
    y.append(scaled_data[i, 4])  # Predict only 'Adj Close' price 

X, y = np.array(X), np.array(y)

# Check shapes of X and y
print("X Shape:", X.shape)
print("y Shape:", y.shape)

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=False))
model.add(Dense(units=1))  # Output only 'Adj Close'

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanSquaredError())

# Train the model
model.fit(X, y, epochs=100, batch_size=100, verbose=1)

# Make predictions for future dates till 2040
future_dates = pd.date_range(start=gold_data.index[-1], end='2040-12-31', freq='ME')  # Use 'ME' for monthly frequency
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back days of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]), verbose=0)
    predicted_prices.append(prediction[0, 0])  # Extract single value

    # Update the data with the new prediction
    last_data = np.vstack([last_data[1:], np.zeros((1, last_data.shape[1]))])  # Shift data forward
    last_data[-1, 4] = prediction[0, 0]  # Update with predicted 'Adj Close'

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), scaled_data.shape[1]))
predicted_prices_scaled[:, 4] = predicted_prices  # Fill only the 'Adj Close' column with predictions
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, 4]

# Create DataFrame to store the predictions
future_df = pd.DataFrame(predicted_prices, index=future_dates, columns=['Adj Close'])

# Plot the predictions for 'Adj Close'
plt.figure(figsize=(14, 7))
plt.plot(gold_data.index, gold_data['Adj Close'], label='Historical Adj Close Prices')
plt.plot(future_df.index, future_df['Adj Close'], label='Predicted Adj Close Prices', linestyle='--')
plt.title('Gold Price Prediction till 2040')
plt.xlabel('Date')
plt.ylabel('Adj Close Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_price_adj_close_predictions_till_2040.csv')
print("Download completed")
# Out:
# Initial Data Shape: (239, 5)
#                   Open        High         Low       Close   Adj Close
# Date
# 2000-09-01  277.000000  278.399994  269.000000  273.600006  273.600006
# 2000-11-01  263.899994  270.200012  263.899994  270.100006  270.100006
# 2000-12-01  269.700012  276.000000  268.000000  272.000000  272.000000
# 2001-01-01  268.399994  268.399994  262.799988  265.600006  265.600006
# 2001-02-01  266.299988  268.899994  255.000000  266.799988  266.799988
# X Shape: (179, 60, 5)
# y Shape: (179,)
# C:\Users\Snapper\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 653ms/step - loss: 0.3722
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 650ms/step - loss: 0.1139
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 634ms/step - loss: 0.0475
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 646ms/step - loss: 0.1443
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 654ms/step - loss: 0.0962
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 714ms/step - loss: 0.0335
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 650ms/step - loss: 0.0636
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 651ms/step - loss: 0.0283
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 657ms/step - loss: 0.0358
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - loss: 0.0432
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 706ms/step - loss: 0.0339
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 705ms/step - loss: 0.0258
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 731ms/step - loss: 0.0311
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 673ms/step - loss: 0.0278
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 738ms/step - loss: 0.0225
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 655ms/step - loss: 0.0235
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 662ms/step - loss: 0.0243
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 667ms/step - loss: 0.0210
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 661ms/step - loss: 0.0199
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 645ms/step - loss: 0.0218
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 704ms/step - loss: 0.0216
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 665ms/step - loss: 0.0189
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 648ms/step - loss: 0.0203
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 726ms/step - loss: 0.0188
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 699ms/step - loss: 0.0195
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 662ms/step - loss: 0.0193
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 658ms/step - loss: 0.0188
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 659ms/step - loss: 0.0185
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 673ms/step - loss: 0.0186
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 670ms/step - loss: 0.0191
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 656ms/step - loss: 0.0187
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 695ms/step - loss: 0.0186
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 674ms/step - loss: 0.0189
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 671ms/step - loss: 0.0183
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 671ms/step - loss: 0.0184
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - loss: 0.0186
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 656ms/step - loss: 0.0181
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 658ms/step - loss: 0.0183
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 653ms/step - loss: 0.0193
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 662ms/step - loss: 0.0192
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 760ms/step - loss: 0.0190
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - loss: 0.0188
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 665ms/step - loss: 0.0178
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 697ms/step - loss: 0.0185
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 702ms/step - loss: 0.0187
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 673ms/step - loss: 0.0181
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 686ms/step - loss: 0.0180
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 676ms/step - loss: 0.0185
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 695ms/step - loss: 0.0179
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 705ms/step - loss: 0.0189
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 664ms/step - loss: 0.0179
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 687ms/step - loss: 0.0185
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 671ms/step - loss: 0.0180
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 670ms/step - loss: 0.0188
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 673ms/step - loss: 0.0182
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 671ms/step - loss: 0.0176
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 651ms/step - loss: 0.0185
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 702ms/step - loss: 0.0182
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 746ms/step - loss: 0.0183
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - loss: 0.0179
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 673ms/step - loss: 0.0178
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 673ms/step - loss: 0.0185
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 656ms/step - loss: 0.0190
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 704ms/step - loss: 0.0181
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 663ms/step - loss: 0.0180
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 671ms/step - loss: 0.0179
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - loss: 0.0186
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 681ms/step - loss: 0.0181
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 673ms/step - loss: 0.0178
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 693ms/step - loss: 0.0181
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 680ms/step - loss: 0.0181
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - loss: 0.0180
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 671ms/step - loss: 0.0173
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 734ms/step - loss: 0.0171
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - loss: 0.0177
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 667ms/step - loss: 0.0177
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 672ms/step - loss: 0.0170
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 702ms/step - loss: 0.0166
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 694ms/step - loss: 0.0175
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 657ms/step - loss: 0.0167
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 688ms/step - loss: 0.0163
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 661ms/step - loss: 0.0174
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 674ms/step - loss: 0.0177
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 693ms/step - loss: 0.0175
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 669ms/step - loss: 0.0169
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 668ms/step - loss: 0.0165
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 743ms/step - loss: 0.0164
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 693ms/step - loss: 0.0164
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 726ms/step - loss: 0.0171
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 691ms/step - loss: 0.0190
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 667ms/step - loss: 0.0184
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 702ms/step - loss: 0.0173
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 670ms/step - loss: 0.0170
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 665ms/step - loss: 0.0175
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 681ms/step - loss: 0.0171
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 687ms/step - loss: 0.0178
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 675ms/step - loss: 0.0165
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 675ms/step - loss: 0.0166
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 687ms/step - loss: 0.0166
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 673ms/step - loss: 0.0159
# Download completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Define tickers
gold_usd_ticker = 'GC=F'  # Gold price in USD
inr_usd_ticker = 'INR=X'  # INR/USD exchange rate

# Fetch data
gold_usd_data = yf.download(gold_usd_ticker, start='2000-01-01', end='2024-01-01', interval='1mo', progress=False)
inr_usd_data = yf.download(inr_usd_ticker, start='2000-01-01', end='2024-01-01', interval='1mo', progress=False)

# Keep necessary columns
gold_usd_data = gold_usd_data[['Close']].rename(columns={'Close': 'Gold Price USD'})
inr_usd_data = inr_usd_data[['Close']].rename(columns={'Close': 'INR/USD'})

# Merge data
data = gold_usd_data.join(inr_usd_data)

# Drop rows with NaN values
data = data.dropna()

# Convert Gold Price to INR per ounce
data['Gold Price INR'] = data['Gold Price USD'] * data['INR/USD']

# Convert from per ounce to per gram
data['Gold Price INR per Gram'] = data['Gold Price INR'] / 31.1035

# Convert from per gram to per 10 grams
data['Gold Price INR per 10 Grams'] = data['Gold Price INR per Gram'] * 10

# Plot the data
plt.figure(figsize=(14, 7))
plt.plot(data.index, data['Gold Price INR per 10 Grams'], label='Gold Price in INR per 10 Grams')
plt.title('Gold Price in INR per 10 Grams')
plt.xlabel('Date')
plt.ylabel('Price (INR)')
plt.legend()
plt.show()

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam
from keras.losses import MeanSquaredError

# For reproducibility
np.random.seed(42)

# Fetch data for the last 20 years with monthly frequency
start_date = '2004-01-01'
end_date = '2024-01-01'

# Download the data for required tickers
tickers = ['INR=X', '^NSEI', '^IXIC', '^GSPC', '^FTSE', '^N225', '^HSI', '^STOXX50E', '^AXJO', '^BVSP']

# Download the data
data = yf.download(tickers, start=start_date, end=end_date, interval='1mo', progress=False)
close_prices = data['Close']

# Download gold price separately
gold_data = yf.download('GC=F', start=start_date, end=end_date, interval='1mo', progress=False)

# Add the 'GC=F' data to close_prices
close_prices['GC=F'] = gold_data['Close']

# Calculate 10gm gold price in INR
close_prices['Gold_INR'] = close_prices['GC=F'] * close_prices['INR=X'] / 10  # Assuming gold is quoted per ounce

# Drop unnecessary columns after calculating Gold_INR
close_prices = close_prices[['Gold_INR'] + [col for col in close_prices.columns if col != 'Gold_INR']]

# Drop rows with NaN values
close_prices = close_prices.dropna()

# Check if there is data to scale
look_back = 60  # Number of previous periods (months) to consider for prediction

if close_prices.empty or len(close_prices) <= look_back:
    raise ValueError("Insufficient data for scaling. Ensure data is correctly processed.")

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(close_prices)

# Prepare the data for LSTM
X, y = [], []

# We will predict only the 'Gold_INR' price
for i in range(look_back, len(scaled_data)):
    X.append(scaled_data[i-look_back:i, :])  # Use all features
    y.append(scaled_data[i, 0])  # Predict only 'Gold_INR' price 

X, y = np.array(X), np.array(y)

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=100, return_sequences=True, input_shape=(X.shape[1], X.shape[2])))
model.add(LSTM(units=100, return_sequences=True))
model.add(LSTM(units=100, return_sequences=False))
model.add(Dense(units=1))  # Output only 'Gold_INR'

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanSquaredError())

# Train the model
model.fit(X, y, epochs=100, batch_size=100, verbose=1)

# Make predictions for future dates till 2040
future_dates = pd.date_range(start=close_prices.index[-1], end='2040-12-31', freq='ME')  # Use 'ME' for monthly frequency
predicted_prices = []

last_data = scaled_data[-look_back:]  # Last look_back days of data

for _ in range(len(future_dates)):
    # Predict the next value
    prediction = model.predict(last_data.reshape(1, look_back, X.shape[2]), verbose=0)
    predicted_prices.append(prediction[0, 0])  # Extract single value

    # Update the data with the new prediction
    last_data = np.vstack([last_data[1:], np.zeros((1, last_data.shape[1]))])  # Shift data forward
    last_data[-1, 0] = prediction[0, 0]  # Update with predicted 'Gold_INR'

# Transform the predictions back to the original scale
predicted_prices_scaled = np.zeros((len(predicted_prices), scaled_data.shape[1]))
predicted_prices_scaled[:, 0] = predicted_prices  # Fill only the 'Gold_INR' column with predictions
predicted_prices = scaler.inverse_transform(predicted_prices_scaled)[:, 0]

# Create DataFrame to store the predictions
future_df = pd.DataFrame(predicted_prices, index=future_dates, columns=['Gold_INR'])

# Plot the predictions for 'Gold_INR'
plt.figure(figsize=(14, 7))
plt.plot(close_prices.index, close_prices['Gold_INR'], label='Historical Gold 10gm INR Prices')
plt.plot(future_df.index, future_df['Gold_INR'], label='Predicted Gold 10gm INR Prices', linestyle='--')
plt.title('10gm Gold Price Prediction in INR till 2040')
plt.xlabel('Date')
plt.ylabel('Gold 10gm INR Price')
plt.legend()
plt.show()

# Save the predictions
future_df.to_csv('gold_10gm_inr_predictions_till_2040.csv')
print("Prediction completed and saved.")
# Out:
# Epoch 1/100
# C:\Users\Snapper\AppData\Local\Temp\ipykernel_3976\1639625009.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close_prices['GC=F'] = gold_data['Close']
# C:\Users\Snapper\AppData\Local\Temp\ipykernel_3976\1639625009.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close_prices['Gold_INR'] = close_prices['GC=F'] * close_prices['INR=X'] / 10  # Assuming gold is quoted per ounce
# C:\Users\Snapper\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Check the actual column names
print(close_prices.columns)

# Assuming the column name might be different, find the correct one
gold_usd_column = 'GC=F'  # Replace this with the actual column name if different

# Calculate 10gm gold price in INR
close_prices.loc[:, 'Gold_INR'] = close_prices[gold_usd_column] * close_prices['INR=X'] / 10  # Assuming gold is quoted per ounce

# Drop unnecessary columns after calculating Gold_INR
close_prices = close_prices[['Gold_INR'] + [col for col in close_prices.columns if col != 'Gold_INR']]
# Out:
# Index(['INR=X', '^AXJO', '^BVSP', '^FTSE', '^GSPC', '^HSI', '^IXIC', '^N225'], dtype='object', name='Ticker')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GC=F'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 8
#       5 gold_usd_column = 'GC=F'  # Replace this with the actual column name if different
#       7 # Calculate 10gm gold price in INR
# ----> 8 close_prices.loc[:, 'Gold_INR'] = close_prices[gold_usd_column] * close_prices['INR=X'] / 10  # Assuming gold is quoted per ounce
#      10 # Drop unnecessary columns after calculating Gold_INR
#      11 close_prices = close_prices[['Gold_INR'] + [col for col in close_prices.columns if col != 'Gold_INR']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'GC=F'

# %%
# Attempt to download 'GC=F' data separately
gold_data = yf.download('GC=F', start='2004-01-01', end='2024-01-01', interval='1mo', progress=False)

if gold_data.empty:
    print("Failed to download 'GC=F' data.")
else:
    print("Successfully downloaded 'GC=F' data.")
    close_prices['GC=F'] = gold_data['Close']  # Adding the 'GC=F' data to the DataFrame
# Out:
# Successfully downloaded 'GC=F' data.
